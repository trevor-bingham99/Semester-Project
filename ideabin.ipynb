# %% [markdown]
# This file is where I tested all the code and explored what the data was like and what might be useful, so this is largely a mess of different code bits scattered about, but could be good to look through to see things I decided to leave out or that I tried but didn't work well.

# %%
import pandas as pd
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
import json

import numpy as np
import time
from itertools import groupby
def scroll(driver, timeout):
    # get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        for i in range(timeout):
            # scroll down
            driver.find_element(By.XPATH,"/html/body/div[7]/div[2]/div/div[1]/div[3]/div/div/div[2]/div/table").send_keys(Keys.END)

            # wait for page to load
            time.sleep(1)

        # get new scroll height and compare to last height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

url = 'https://services1.arcgis.com/99lidPhWCzftIe9K/arcgis/rest/services/HousingUnitInventory/FeatureServer/0/query?where=1%3D1&outFields=*&returnGeometry=false&outSR=4326&f=json'
url1= 'https://opendata.gis.utah.gov/datasets/utah::utah-housing-unit-inventory/about'

# %%
driver.get(url)

# %%
pre = driver.find_element(By.TAG_NAME,"pre").text
data = json.loads(pre)

df = pd.json_normalize(data['features'])

new_column_names = {col: col.replace('attributes.', '') for col in df.columns}
df.rename(columns=new_column_names, inplace=True)
df.set_index('OBJECTID', inplace=True)

# %%
df
# Out:
#           UNIT_ID           TYPE        SUBTYPE IS_OUG  UNIT_COUNT    DUA  \
# OBJECTID
# 1               1  single_family  single_family      1          18  9.339
# 2               2  single_family  single_family      1          34  5.609
# 3               3  single_family  single_family      1          40  9.383
# 4               4  single_family  single_family      1          29  4.463
# 5               5  single_family  single_family      1          24  6.170
# ...           ...            ...            ...    ...         ...    ...
# 1996         1996  single_family  single_family      0           1  4.751
# 1997         1997  single_family  single_family      0           1  4.697
# 1998         1998  single_family  single_family      0           1  4.683
# 1999         1999  single_family  single_family      0           1  4.699
# 2000         2000  single_family  single_family      0           1  3.899
#
#              ACRES  TOT_BD_FT2  TOT_VALUE  APX_BLT_YR  BLT_DECADE  \
# OBJECTID
# 1         1.927313       26873    4935167        2002        2000
# 2         6.061556       47226   10518205        2007        2000
# 3         4.263039       52295    9844160        2007        2000
# 4         6.497216       55105   12752774        2016        2010
# 5         3.890075       19183    4691610        2011        2010
# ...            ...         ...        ...         ...         ...
# 1996      0.210503        1515     347000        1976        1970
# 1997      0.212897        1470     341000        1976        1970
# 1998      0.213535        1477     326000        1976        1970
# 1999      0.212812        1384     340000        1976        1970
# 2000      0.256454        1386     352000        1976        1970
#
#                      CITY COUNTY           SUBCOUNTY   Shape__Area  \
# OBJECTID
# 1             Woods Cross  Davis  South Davis County  13663.433594
# 2             Centerville  Davis  South Davis County  43042.921875
# 3             Centerville  Davis  South Davis County  30273.128906
# 4             Centerville  Davis  South Davis County  46168.941406
# 5              Farmington  Davis  South Davis County  27656.757812
# ...                   ...    ...                 ...           ...
# 1996      North Salt Lake  Davis  South Davis County   1490.750000
# 1997      North Salt Lake  Davis  South Davis County   1507.695312
# 1998      North Salt Lake  Davis  South Davis County   1512.195312
# 1999      North Salt Lake  Davis  South Davis County   1507.078125
# 2000      North Salt Lake  Davis  South Davis County   1816.117188
#
#           Shape__Length
# OBJECTID
# 1            576.740589
# 2            934.399608
# 3           1323.902677
# 4            925.352925
# 5            738.090710
# ...                 ...
# 1996         154.555647
# 1997         157.908761
# 1998         158.134178
# 1999         157.869905
# 2000         182.016226
#
# [2000 rows x 16 columns]

# %%
driver.get(url1)

# %%
driver.find_element(By.ID,"ember99").click()

# %%
driver.find_element(By.ID,"ember241-title").click()
driver.find_element(By.ID,"ember241-title").click()

# %%
table =driver.find_element(By.XPATH,"/html/body/div[7]/div[2]/div/div[1]/div[3]/div/div/div[2]/div/table") 
table
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="40a6ce48e958ab31b0b9b5c9df186455", element="F52F23C00A0F7F69ACAB7F095E22DAC4_element_46")>

# %%
table.send_keys(Keys.PAGE_DOWN)

# %%
def get_all_rows(driver, table_locator):
    # Scroll to the bottom of the page to ensure all rows are loaded
    last_row_count = 0

    while True:
        # Record the current number of rows
        current_row_count = len(driver.find_elements(By.XPATH, table_locator + "//tr"))

        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait for a short time to let new rows load
        scroll(driver,10)

        # Get the new number of rows
        new_row_count = len(driver.find_elements(By.XPATH, table_locator + "//tr"))

        # If the number of rows hasn't increased, break the loop
        if new_row_count == current_row_count:
            break

        # Update the last row count
        last_row_count = new_row_count

    html = driver.page_source

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')

    # Find the table in the parsed HTML
    table = soup.find('table')

    # Check if the table was found
    if table:
        # Extract all rows from the table
        all_rows = table.find_all('tr')
        return all_rows
    else:
        print("Table not found.")
        return []    


# Replace with the correct XPath or other locator for your table
table_locator = "/html/body/div[7]/div[2]/div/div[1]/div[3]/div/div/div[2]/div/table"

all_rows = get_all_rows(driver, table_locator)

# Now 'all_rows' contains all the rows in the table
len(all_rows)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[5], line 45
#      42 # Replace with the correct XPath or other locator for your table
#      43 table_locator = "/html/body/div[7]/div[2]/div/div[1]/div[3]/div/div/div[2]/div/table"
# ---> 45 all_rows = get_all_rows(driver, table_locator)
#      47 # Now 'all_rows' contains all the rows in the table
#      48 len(all_rows)
#
# Cell In[5], line 12, in get_all_rows(driver, table_locator)
#       9 driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#      11 # Wait for a short time to let new rows load
# ---> 12 scroll(driver,10)
#      14 # Get the new number of rows
#      15 new_row_count = len(driver.find_elements(By.XPATH, table_locator + "//tr"))
#
# Cell In[1], line 24, in scroll(driver, timeout)
#      21 while True:
#      22     for i in range(timeout):
#      23         # scroll down
# ---> 24         driver.find_element(By.XPATH,"/html/body/div[7]/div[2]/div/div[1]/div[3]/div/div/div[2]/div/table").send_keys(Keys.END)
#      26         # wait for page to load
#      27         time.sleep(1)
#
# File ~/anaconda3/envs/stat386/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:738, in WebDriver.find_element(self, by, value)
#     735     by = By.CSS_SELECTOR
#     736     value = f'[name="{value}"]'
# --> 738 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/anaconda3/envs/stat386/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File ~/anaconda3/envs/stat386/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=120.0.6099.71)
# Stacktrace:
# 0   chromedriver                        0x000000010113c4cc chromedriver + 4162764
# 1   chromedriver                        0x0000000101134654 chromedriver + 4130388
# 2   chromedriver                        0x0000000100d8bbc0 chromedriver + 293824
# 3   chromedriver                        0x0000000100d730b0 chromedriver + 192688
# 4   chromedriver                        0x0000000100d72fd8 chromedriver + 192472
# 5   chromedriver                        0x0000000100e112b0 chromedriver + 840368
# 6   chromedriver                        0x0000000100dc56bc chromedriver + 530108
# 7   chromedriver                        0x0000000100dc6930 chromedriver + 534832
# 8   chromedriver                        0x0000000101101df8 chromedriver + 3923448
# 9   chromedriver                        0x00000001011063cc chromedriver + 3941324
# 10  chromedriver                        0x00000001010ea028 chromedriver + 3825704
# 11  chromedriver                        0x0000000101106f2c chromedriver + 3944236
# 12  chromedriver                        0x00000001010dc6e4 chromedriver + 3770084
# 13  chromedriver                        0x0000000101123970 chromedriver + 4061552
# 14  chromedriver                        0x0000000101123ae8 chromedriver + 4061928
# 15  chromedriver                        0x00000001011342d4 chromedriver + 4129492
# 16  libsystem_pthread.dylib             0x00000001806f6034 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x00000001806f0e3c thread_start + 8

# %%
all_rows1=all_rows

# %%
header_columns = [span.get_text(strip=True) for span in all_rows1[0].find_all('span', {'role': 'button'})]

# Initialize an empty list to store row data
all_rows_data = []

# Iterate through each row
for row_html in all_rows1:
    # Extract data from each cell in the row
    data = [cell.get_text(strip=True) for cell in row_html.find_all('td', {'role': 'gridcell'})]
    
    # Create a dictionary for the row
    row_dict = dict(zip(header_columns, data))
    
    # Append the row data to the list
    all_rows_data.append(row_dict)

# Create a DataFrame from the list of row data
df = pd.DataFrame(all_rows_data)

# %%
df.dropna(inplace=True)
df
# Out:
#        UNIT_ID           TYPE        SUBTYPE IS_OUG UNIT_COUNT      DUA  \
# 1      146,644  single_family  single_family      1        583     1.27
# 2      391,092  single_family  single_family      1        641      4.9
# 3      391,629   multi_family          condo      1        424  119.822
# 4      387,152   multi_family          condo      1        357  196.182
# 5      387,183   multi_family          condo      1        167  543.412
# ...        ...            ...            ...    ...        ...      ...
# 21796   53,134  single_family  single_family      0          1    3.404
# 21797   93,987  single_family  single_family      0          1    2.851
# 21798   99,156  single_family  single_family      0          1    2.423
# 21799  134,657  single_family  single_family      0          1    2.119
# 21800  169,322  single_family  single_family      0          1    3.005
#
#          ACRES TOT_BD_FT2    TOT_VALUE APX_BLT_YR BLT_DECADE             CITY  \
# 1      458.888  3,528,545  550,840,200      2,019      2,010            Sandy
# 2      130.817  1,525,269  253,029,578      2,013      2,010  North Salt Lake
# 3        3.539  1,226,704  177,524,300      2,004      2,000   Salt Lake City
# 4         1.82    661,616  167,118,800      1,983      1,980   Salt Lake City
# 5        0.307    232,991  144,316,300      2,011      2,010   Salt Lake City
# ...        ...        ...          ...        ...        ...              ...
# 21796    0.294      3,432      709,000      2,015      2,010        Kaysville
# 21797    0.351      3,018      709,000      2,003      2,000            Ogden
# 21798    0.413      2,754      709,000      2,004      2,000      South Ogden
# 21799    0.472      2,273      709,000      2,016      2,010    Pleasant View
# 21800    0.333      6,166      709,000      2,006      2,000         Riverton
#
#           COUNTY                   SUBCOUNTY    Shape__Area Shape__Length
# 1      Salt Lake  Southeast Salt Lake County  3,222,044.828    10,972.598
# 2          Davis          South Davis County    926,988.477     4,009.061
# 3      Salt Lake      North Salt Lake County     25,007.223       745.823
# 4      Salt Lake      North Salt Lake County     12,858.336       463.557
# 5      Salt Lake      North Salt Lake County      2,171.895       187.501
# ...          ...                         ...            ...           ...
# 21796      Davis          South Davis County       2,093.48       197.192
# 21797      Weber          South Weber County      2,510.375       210.261
# 21798      Weber          South Weber County      2,951.859       222.862
# 21799      Weber          North Weber County      3,391.539       241.691
# 21800  Salt Lake  Southwest Salt Lake County      2,335.059       195.434
#
# [21800 rows x 16 columns]

# %%
soup = BeautifulSoup(all_rows1, 'html.parser')


columns = [cell['data-col'] for cell in soup.find_all('td', {'role': 'gridcell'})]
data = [cell.get_text() for cell in soup.find_all('td', {'role': 'gridcell'})]

# Create a dictionary to construct a DataFrame
data_dict = dict(zip(columns, data))

# Create a DataFrame from the dictionary
df = pd.DataFrame([data_dict])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 soup = BeautifulSoup(all_rows1, 'html.parser')
#       4 columns = [cell['data-col'] for cell in soup.find_all('td', {'role': 'gridcell'})]
#       5 data = [cell.get_text() for cell in soup.find_all('td', {'role': 'gridcell'})]
#
# File ~/anaconda3/envs/stat386/lib/python3.10/site-packages/bs4/__init__.py:328, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     326 rejections = []
#     327 success = False
# --> 328 for (self.markup, self.original_encoding, self.declared_html_encoding,
#     329  self.contains_replacement_characters) in (
#     330      self.builder.prepare_markup(
#     331          markup, from_encoding, exclude_encodings=exclude_encodings)):
#     332     self.reset()
#     333     self.builder.initialize_soup(self)
#
# File ~/anaconda3/envs/stat386/lib/python3.10/site-packages/bs4/builder/_htmlparser.py:361, in HTMLParserTreeBuilder.prepare_markup(self, markup, user_specified_encoding, document_declared_encoding, exclude_encodings)
#     358 user_encodings = [document_declared_encoding]
#     360 try_encodings = [user_specified_encoding, document_declared_encoding]
# --> 361 dammit = UnicodeDammit(
#     362     markup,
#     363     known_definite_encodings=known_definite_encodings,
#     364     user_encodings=user_encodings,
#     365     is_html=True,
#     366     exclude_encodings=exclude_encodings
#     367 )
#     368 yield (dammit.markup, dammit.original_encoding,
#     369        dammit.declared_html_encoding,
#     370        dammit.contains_replacement_characters)
#
# File ~/anaconda3/envs/stat386/lib/python3.10/site-packages/bs4/dammit.py:601, in UnicodeDammit.__init__(self, markup, known_definite_encodings, smart_quotes_to, is_html, exclude_encodings, user_encodings, override_encodings)
#     598 self.markup = self.detector.markup
#     600 u = None
# --> 601 for encoding in self.detector.encodings:
#     602     markup = self.detector.markup
#     603     u = self._convert_from(encoding)
#
# File ~/anaconda3/envs/stat386/lib/python3.10/site-packages/bs4/dammit.py:434, in EncodingDetector.encodings(self)
#     431 # Look within the document for an XML or HTML encoding
#     432 # declaration.
#     433 if self.declared_encoding is None:
# --> 434     self.declared_encoding = self.find_declared_encoding(
#     435         self.markup, self.is_html)
#     436 if self._usable(self.declared_encoding, tried):
#     437     yield self.declared_encoding
#
# File ~/anaconda3/envs/stat386/lib/python3.10/site-packages/bs4/dammit.py:511, in EncodingDetector.find_declared_encoding(cls, markup, is_html, search_entire_document)
#     509 html_re = res['html']
#     510 declared_encoding = None
# --> 511 declared_encoding_match = xml_re.search(markup, endpos=xml_endpos)
#     512 if not declared_encoding_match and is_html:
#     513     declared_encoding_match = html_re.search(markup, endpos=html_endpos)
#
# TypeError: expected string or bytes-like object

# %%
len(all_rows)
# Out:
# 26

# %%
scroll(driver,10)

# %%
pre = driver.find_element(By.TAG_NAME,"pre").text
data = json.loads(pre)
print(pre)
# Out:
# {"objectIdFieldName":"OBJECTID","uniqueIdField":{"name":"OBJECTID","isSystemMaintained":true},"globalIdFieldName":"","geometryProperties":{"shapeAreaFieldName":"Shape__Area","shapeLengthFieldName":"Shape__Length","units":"esriMeters"},"geometryType":"esriGeometryPolygon","spatialReference":{"wkid":4326,"latestWkid":4326},"fields":[{"name":"OBJECTID","type":"esriFieldTypeOID","alias":"OBJECTID","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"UNIT_ID","type":"esriFieldTypeInteger","alias":"UNIT_ID","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"TYPE","type":"esriFieldTypeString","alias":"TYPE","sqlType":"sqlTypeOther","length":26,"domain":null,"defaultValue":null},{"name":"SUBTYPE","type":"esriFieldTypeString","alias":"SUBTYPE","sqlType":"sqlTypeOther","length":44,"domain":null,"defaultValue":null},{"name":"IS_OUG","type":"esriFieldTypeString","alias":"IS_OUG","sqlType":"sqlTypeOther","length":2,"domain":null,"defaultValue":null},{"name":"UNIT_COUNT","type":"esriFieldTypeDouble","alias":"UNIT_COUNT","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"DUA","type":"esriFieldTypeDouble","alias":"DUA","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"ACRES","type":"esriFieldTypeDouble","alias":"ACRES","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"TOT_BD_FT2","type":"esriFieldTypeDouble","alias":"TOT_BD_FT2","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"TOT_VALUE","type":"esriFieldTypeDouble","alias":"TOT_VALUE","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"APX_BLT_YR","type":"esriFieldTypeDouble","alias":"APX_BLT_YR","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"BLT_DECADE","type":"esriFieldTypeInteger","alias":"BLT_DECADE","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"CITY","type":"esriFieldTypeString","alias":"CITY","sqlType":"sqlTypeOther","length":40,"domain":null,"defaultValue":null},{"name":"COUNTY","type":"esriFieldTypeString","alias":"COUNTY","sqlType":"sqlTypeOther","length":18,"domain":null,"defaultValue":null},{"name":"SUBCOUNTY","type":"esriFieldTypeString","alias":"SUBCOUNTY","sqlType":"sqlTypeOther","length":52,"domain":null,"defaultValue":null},{"name":"Shape__Area","type":"esriFieldTypeDouble","alias":"Shape__Area","sqlType":"sqlTypeDouble","domain":null,"defaultValue":null},{"name":"Shape__Length","type":"esriFieldTypeDouble","alias":"Shape__Length","sqlType":"sqlTypeDouble","domain":null,"defaultValue":null}],"exceededTransferLimit":true,"features":[{"attributes":{"OBJECTID":1,"UNIT_ID":1,"TYPE":"single_family","SUBTYPE":"single_family","IS_OUG":"1","UNIT_COUNT":18,"DUA":9.339,"ACRES":1.92731315,"TOT_BD_FT2":26873,"TOT_VALUE":4935167,"APX_BLT_YR":2002,"BLT_DECADE":2000,"CITY":"Woods Cross","COUNTY":"Davis","SUBCOUNTY":"South Davis County","Shape__Area":13663.43359375,"Shape__Length":576.740588578099}},{"attributes":{"OBJECTID":2,"UNIT_ID":2,"TYPE":"single_family","SUBTYPE":"single_family","IS_OUG":"1","UNIT_COUNT":34,"DUA":5.609,"ACRES":6.06155618,"TOT_BD_FT2":47226,"TOT_VALUE":10518205,"APX_BLT_YR":2007,"BLT_DECADE":2000,"CITY":"Centerville","COUNTY":"Davis","SUBCOUNTY":"South Davis County","Shape__Area":43042.921875,"Shape__Length":934.399607880772}},{"attributes":{"OBJECTID":3,"UNIT_ID":3,"TYPE":"single_family","SUBTYPE":"single_family","IS_OUG":"1","UNIT_COUNT":40,"DUA":9.383,"ACRES":4.26303887,"TOT_BD_FT2":52295,"TOT_VALUE":9844160,"APX_BLT_YR":2007,"BLT_DECADE":2000,"CITY":"Centerville","COUNTY":"Davis","SUBCOUNTY":"South Davis County","Shape__Area":30273.12890625,"Shape__Length":1323.90267722008}},{"attributes":{"OBJECTID":4,"UNIT_ID":4,"TYPE":"single_family","SUBTYPE":"single_family","IS_OUG":"1","UNIT_COUNT":29,"DUA":4.463,"ACRES":6.49721617,"TOT_BD_FT2":55105,"TOT_VALUE":12752774,"APX_BLT_YR":2016,"BLT_DECADE":2010,"CITY":"Centerville","COUNTY":"Davis","SUBCOUNTY":"South Davis County","Shape__Area":46168.94140625," ...

# %%
df1 = pd.json_normalize(data['features'])
new_column_names = {col: col.replace('attributes.', '') for col in df1.columns}
df1.rename(columns=new_column_names, inplace=True)
df1.set_index('OBJECTID', inplace=True)

# %%
df[df['APX_BLT_YR'] == ""]
# Out:
#        UNIT_ID           TYPE           SUBTYPE IS_OUG UNIT_COUNT     DUA  \
# 37     391,405   multi_family         apartment      0         24   23.99
# 95     391,368   multi_family         apartment      0         36  18.202
# 145    391,307   multi_family             condo      1        286  27.254
# 177    387,267   multi_family             condo      1        228  24.056
# 232    390,217   multi_family         apartment      0        310  68.488
# 246    390,239   multi_family         apartment      0        374  20.527
# 446    391,084   multi_family         apartment      0        190  20.731
# 451    387,271   multi_family             condo      1        121   24.15
# 504    390,204   multi_family         apartment      0        249  36.262
# 523    391,686   multi_family             condo      0         68   69.94
# 589    386,969   multi_family             condo      1         39   29.18
# 795    391,457   multi_family         apartment      0        198  26.812
# 851    387,272   multi_family             condo      1         61  37.116
# 938    391,652   multi_family         apartment      0        121  24.468
# 983    391,066   multi_family         apartment      0         70  72.551
# 1026   387,193   multi_family             condo      1         31  33.532
# 1369   387,109   multi_family          townhome      1         20  41.544
# 1576   387,300   multi_family          townhome      1         15  15.211
# 1661   391,705   multi_family             condo      1         60  29.536
# 1848   145,561   multi_family          townhome      1        127  11.614
# 1882   386,760   multi_family          townhome      1         12   11.31
# 1883   387,287   multi_family             condo      1         12   11.31
# 1929   223,906  single_family     single_family      0          1   0.118
# 1986   391,530   multi_family         apartment      0         24  27.452
# 1987   391,531   multi_family         apartment      0         24  27.452
# 2336   391,684   multi_family         apartment      0         76   14.94
# 2339   387,227   multi_family          townhome      1          4   8.071
# 2553   387,282   multi_family             condo      1         13  18.167
# 2614   387,242   multi_family          townhome      1          3   6.953
# 2667   387,114   multi_family          townhome      1          6  17.339
# 2773   391,078   multi_family         apartment      0         21  31.132
# 3236   390,214   multi_family         apartment      0         18  12.877
# 3249   387,288   multi_family             condo      1          6   12.12
# 3554   386,762   multi_family          townhome      1          7   8.981
# 3583   387,286   multi_family             condo      1          7  12.528
# 3660   387,000   multi_family          townhome      1         10   8.012
# 4136   391,608   multi_family         apartment      1         93  44.786
# 4158   391,692   multi_family         apartment      0         10   4.997
# 4213   386,344   multi_family          townhome      1         42  11.684
# 4681   391,491   multi_family  mobile_home_park      1         30   8.893
# 4957   386,764   multi_family          townhome      1          5  15.032
# 4958   387,285   multi_family             condo      1          5  15.032
# 5018   391,636   multi_family         apartment      0          1      10
# 5021   387,764   multi_family         apartment      0         10  64.674
# 5834   391,634   multi_family         apartment      0          1   9.706
# 6785   146,863  single_family     single_family      1          1   0.283
# 7812   391,703   multi_family             condo      1          4  11.677
# 7839   387,235   multi_family             condo      1          4  25.366
# 8357   386,919   multi_family          townhome      1          2   6.917
# 9642   145,563   multi_family          townhome      1         28  16.158
# 10429  387,229   multi_family          townhome      1          3  19.189
# 18745  386,926   multi_family          townhome      1          2  10.916
# 18837  386,922   multi_family          townhome      1          2   8.339
# 20825  145,569   multi_family         apartment      1         36  87.331
#
#         ACRES TOT_BD_FT2   TOT_VALUE APX_BLT_YR BLT_DECADE             CITY  \
# 37          1    492,435  81,926,100                     0          Midvale
# 95      1.978          0  60,286,200                     0     Taylorsville
# 145    10.494          0  52,165,800                     0         Herriman
# 177     9.478    126,500  47,636,700                     0         Herriman
# 232     4.526    266,946  40,249,500                     0           Draper
# 246     18.22    421,957  39,432,100                     0          Midvale
# 446     9.165    198,580  25,740,000                     0          Midvale
# 451      5.01    114,480  25,489,400                     0         Herriman
# 504     6.867          0  23,172,100                     0           Draper
# 523     0.972          0  22,347,900                     0     South Jordan
# 589     1.337     37,868  20,217,500                     0         Holladay
# 795     7.385    188,234  14,913,600                     0   Salt Lake City
# 851     1.643     50,880  13,724,000                     0         Herriman
# 938     4.945    107,519  12,291,800                     0           Draper
# 983     0.965     66,000  11,691,700                     0  South Salt Lake
# 1026    0.924     29,095  11,164,500                     0   Salt Lake City
# 1369    0.481          0   7,648,200                     0   Salt Lake City
# 1576    0.986          0   6,426,000                     0           Draper
# 1661    2.031     42,816   5,990,346                     0      South Ogden
# 1848   10.935          0   5,087,102                     0       West Haven
# 1882    1.061     19,656   4,990,900                     0     South Jordan
# 1883    1.061     19,656   4,990,900                     0     South Jordan
# 1929     8.51      2,450   4,850,000                     0         Holladay
# 1986    0.874     38,657   4,643,500                     0  South Salt Lake
# 1987    0.874     38,657   4,643,500                     0  South Salt Lake
# 2336    5.087     74,142   3,752,800                     0   Salt Lake City
# 2339    0.496     13,605   3,746,100                     0   Salt Lake City
# 2553    0.716     14,137   3,319,200                     0     South Jordan
# 2614    0.431     12,046   3,223,900                     0   Salt Lake City
# 2667    0.346     13,412   3,135,400                     0   Salt Lake City
# 2773    0.675     28,704   2,963,300                     0   Salt Lake City
# 3236    1.398     24,192   2,389,300                     0           Draper
# 3249    0.495          0   2,380,200                     0     South Jordan
# 3554    0.779     11,764   2,122,000                     0     South Jordan
# 3583    0.559     11,764   2,104,400                     0     South Jordan
# 3660    1.248          0   2,054,200                     0        Millcreek
# 4136    2.077          0   1,781,661                     0            Ogden
# 4158    2.001     24,647   1,772,900                     0  South Salt Lake
# 4213    3.595          0   1,747,700                     0      West Jordan
# 4681    3.373          0   1,580,500                     0   Salt Lake City
# 4957    0.333      8,138   1,504,700                     0     South Jordan
# 4958    0.333      8,138   1,504,700                     0     South Jordan
# 5018      0.1          0   1,489,000                     0   Salt Lake City
# 5021    0.155     11,588   1,488,100                     0   Salt Lake City
# 5834    0.103          0   1,321,100                     0   Salt Lake City
# 6785    3.534          0   1,190,200                     0   Salt Lake City
# 7812    0.343      6,920   1,094,029                     0      South Ogden
# 7839    0.158      5,123   1,092,700                     0   Salt Lake City
# 8357    0.289      5,856   1,054,600                     0           Murray
# 9642    1.733          0     980,046                     0       West Haven
# 10429   0.156          0     945,500                     0   Salt Lake City
# 18745   0.183          0     747,900                     0         Holladay
# 18837    0.24      4,913     746,400                     0           Murray
# 20825   0.412          0     720,008                     0            Ogden
#
#           COUNTY                   SUBCOUNTY  Shape__Area Shape__Length
# 37     Salt Lake  Southeast Salt Lake County    7,040.309       404.432
# 95     Salt Lake  Southwest Salt Lake County   13,941.148       488.067
# 145    Salt Lake  Southwest Salt Lake County   73,535.785     1,122.367
# 177    Salt Lake  Southwest Salt Lake County   66,422.914     1,129.673
# 232    Salt Lake  Southeast Salt Lake County   31,744.836        997.35
# 246    Salt Lake  Southeast Salt Lake County  128,148.063     1,840.377
# 446    Salt Lake  Southeast Salt Lake County   64,453.988     1,186.785
# 451    Salt Lake  Southwest Salt Lake County   35,137.535       779.745
# 504    Salt Lake  Southeast Salt Lake County   48,149.234       934.128
# 523    Salt Lake  Southwest Salt Lake County    6,823.805        360.66
# 589    Salt Lake  Southeast Salt Lake County    9,417.613       491.476
# 795    Salt Lake      North Salt Lake County   52,115.375     1,443.275
# 851    Salt Lake  Southwest Salt Lake County   11,526.652        787.86
# 938    Salt Lake  Southeast Salt Lake County   34,653.797       838.651
# 983    Salt Lake      North Salt Lake County    6,804.938       329.762
# 1026   Salt Lake      North Salt Lake County    6,534.039       353.284
# 1369   Salt Lake      North Salt Lake County    3,399.012       233.679
# 1576   Salt Lake  Southeast Salt Lake County     6,919.48       346.396
# 1661       Weber          South Weber County   14,526.668       552.404
# 1848       Weber          South Weber County   78,270.809     1,177.117
# 1882   Salt Lake  Southwest Salt Lake County    7,451.473       419.201
# 1883   Salt Lake  Southwest Salt Lake County    7,451.473       419.201
# 1929   Salt Lake  Southeast Salt Lake County   59,943.961     1,099.408
# 1986   Salt Lake      North Salt Lake County    6,167.574       328.829
# 1987   Salt Lake      North Salt Lake County    6,167.574       328.829
# 2336   Salt Lake      North Salt Lake County   35,981.516       825.773
# 2339   Salt Lake      North Salt Lake County     3,503.27       325.247
# 2553   Salt Lake  Southwest Salt Lake County    5,023.719       304.447
# 2614   Salt Lake      North Salt Lake County    3,050.777       274.495
# 2667   Salt Lake      North Salt Lake County    2,443.457         212.2
# 2773   Salt Lake      North Salt Lake County    4,768.332       340.534
# 3236   Salt Lake  Southeast Salt Lake County    9,802.039       614.826
# 3249   Salt Lake  Southwest Salt Lake County    3,476.875       274.765
# 3554   Salt Lake  Southwest Salt Lake County    5,473.676       310.881
# 3583   Salt Lake  Southwest Salt Lake County    3,923.781       275.352
# 3660   Salt Lake      North Salt Lake County    8,796.797        376.54
# 4136       Weber          South Weber County   14,877.148       501.061
# 4158   Salt Lake      North Salt Lake County   14,111.453       679.792
# 4213   Salt Lake  Southwest Salt Lake County   25,279.383        643.98
# 4681   Salt Lake      North Salt Lake County   23,843.289       779.694
# 4957   Salt Lake  Southwest Salt Lake County    2,335.824       210.365
# 4958   Salt Lake  Southwest Salt Lake County    2,335.824       210.365
# 5018   Salt Lake      North Salt Lake County      706.359       132.713
# 5021   Salt Lake      North Salt Lake County    1,092.797        148.25
# 5834   Salt Lake      North Salt Lake County      727.758        133.52
# 6785   Salt Lake      North Salt Lake County   25,001.066       661.229
# 7812       Weber          South Weber County    2,449.406       351.015
# 7839   Salt Lake      North Salt Lake County    1,114.875       145.076
# 8357   Salt Lake  Southeast Salt Lake County    2,035.688       181.277
# 9642       Weber          South Weber County   12,407.672     1,007.515
# 10429  Salt Lake      North Salt Lake County    1,105.137       166.039
# 18745  Salt Lake  Southeast Salt Lake County    1,290.148       151.662
# 18837  Salt Lake  Southeast Salt Lake County    1,688.434       176.422
# 20825      Weber          South Weber County    2,953.371       243.489

# %%
df1.reset_index().drop(columns='OBJECTID')
# Out:
#       UNIT_ID           TYPE        SUBTYPE IS_OUG  UNIT_COUNT    DUA  \
# 0           1  single_family  single_family      1          18  9.339
# 1           2  single_family  single_family      1          34  5.609
# 2           3  single_family  single_family      1          40  9.383
# 3           4  single_family  single_family      1          29  4.463
# 4           5  single_family  single_family      1          24  6.170
# ...       ...            ...            ...    ...         ...    ...
# 1995     1996  single_family  single_family      0           1  4.751
# 1996     1997  single_family  single_family      0           1  4.697
# 1997     1998  single_family  single_family      0           1  4.683
# 1998     1999  single_family  single_family      0           1  4.699
# 1999     2000  single_family  single_family      0           1  3.899
#
#          ACRES  TOT_BD_FT2  TOT_VALUE  APX_BLT_YR  BLT_DECADE  \
# 0     1.927313       26873    4935167        2002        2000
# 1     6.061556       47226   10518205        2007        2000
# 2     4.263039       52295    9844160        2007        2000
# 3     6.497216       55105   12752774        2016        2010
# 4     3.890075       19183    4691610        2011        2010
# ...        ...         ...        ...         ...         ...
# 1995  0.210503        1515     347000        1976        1970
# 1996  0.212897        1470     341000        1976        1970
# 1997  0.213535        1477     326000        1976        1970
# 1998  0.212812        1384     340000        1976        1970
# 1999  0.256454        1386     352000        1976        1970
#
#                  CITY COUNTY           SUBCOUNTY   Shape__Area  Shape__Length
# 0         Woods Cross  Davis  South Davis County  13663.433594     576.740589
# 1         Centerville  Davis  South Davis County  43042.921875     934.399608
# 2         Centerville  Davis  South Davis County  30273.128906    1323.902677
# 3         Centerville  Davis  South Davis County  46168.941406     925.352925
# 4          Farmington  Davis  South Davis County  27656.757812     738.090710
# ...               ...    ...                 ...           ...            ...
# 1995  North Salt Lake  Davis  South Davis County   1490.750000     154.555647
# 1996  North Salt Lake  Davis  South Davis County   1507.695312     157.908761
# 1997  North Salt Lake  Davis  South Davis County   1512.195312     158.134178
# 1998  North Salt Lake  Davis  South Davis County   1507.078125     157.869905
# 1999  North Salt Lake  Davis  South Davis County   1816.117188     182.016226
#
# [2000 rows x 16 columns]

# %%
combined_df = pd.concat([df, df1], ignore_index=True)
combined_df.drop_duplicates(subset='UNIT_ID', keep='first',inplace=True)

# %%
columns_to_convert_to_int = ['UNIT_ID', 'UNIT_COUNT', 'DUA','ACRES','TOT_BD_FT2','TOT_VALUE','APX_BLT_YR','BLT_DECADE','Shape__Area','Shape__Length','IS_OUG']

# Convert specified columns to int
combined_df[columns_to_convert_to_int] = combined_df[columns_to_convert_to_int].replace(",","",regex=True).replace('', 0).astype(float)

# %%
combined_df = pd.read_csv("./HousingData.csv")

# %%
import plotly.express as px

correlation_matrix = combined_df.corr(numeric_only=True)

# Create a heatmap of the correlation matrix
fig = px.imshow(
    correlation_matrix,
    labels=dict(x="Features", y="Features", color="Correlation"),
    x=correlation_matrix.columns,
    y=correlation_matrix.columns,
    title='Correlation Heatmap'
)
fig.show()

# %%
import plotly.io as pio
pio.write_image(fig,'../trevor-bingham99.github.io/assets/images/val_vs_year.png')

# %%
import plotly.express as px
fig = px.scatter(combined_df[(combined_df['APX_BLT_YR']!=0) & (combined_df['TOT_BD_FT2']<9000000)], x='TOT_VALUE', y='TOT_BD_FT2', title='Price vs Square Footage',opacity=.5)
fig.show()

# %%
import plotly.express as px
fig = px.scatter(combined_df[(combined_df['APX_BLT_YR']!=0) & (combined_df['TOT_BD_FT2']<9000000)], x='APX_BLT_YR', y='TOT_VALUE', color='SUBTYPE', title='Year Built vs Price',opacity=.5)
fig.show()

# %%
fig = px.scatter(combined_df[(combined_df['APX_BLT_YR']!=0) & (combined_df['TOT_VALUE']<300000000) & (combined_df['ACRES']<500)], x='ACRES', y='TOT_VALUE', color='SUBTYPE', title='Acres of Land vs Total Value',opacity=.5)
fig.show()

# %%
combined_df.to_csv('./HousingData.csv')

# %%
fig = px.histogram(
    combined_df[combined_df['TOT_VALUE']<10000000],
    x='TOT_VALUE',
    title='Distribution of Total Values',
    nbins=50,  # Specify the number of bins
    opacity=0.7  # Set opacity
)
fig.show()

# %%
category_counts = combined_df['SUBTYPE'].value_counts()

# Exclude categories with a count of 0
filtered_counts = category_counts[category_counts != 0]

# Create the bar chart with the filtered counts
fig = px.bar(x=filtered_counts.index, y=filtered_counts.values, text=filtered_counts.values,color=filtered_counts.index,title='Counts of Each Housing Subtype')
fig.show()

# %%
fig = px.scatter(combined_df, x='TOT_VALUE', y='TOT_BD_FT2', color='SUBTYPE', title='Scatter Plot with Plotly Express',opacity=.5)
fig.show()

# %%
sns.displot(df,x='APX_BLT_YR',bins=20)
